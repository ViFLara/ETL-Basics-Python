# %%
import pandas as pd
import pandera as pa

# %% [markdown]
# # Data Extraction

# %%
df = pd.read_csv("ocorrencia_2010_2020.csv", sep = ";", parse_dates=['ocorrencia_dia'], dayfirst = True)
df.head(10)
# Out:
#    codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 0              40211               40211                INCIDENTE
# 1              40349               40349                INCIDENTE
# 2              40351               40351                INCIDENTE
# 3              39527               39527                 ACIDENTE
# 4              40324               40324                INCIDENTE
# 5              39807               39807                INCIDENTE
# 6              40215               40215                INCIDENTE
# 7              39707               39707          INCIDENTE GRAVE
# 8              39156               39156          INCIDENTE GRAVE
# 9              39711               39711          INCIDENTE GRAVE
#
#     ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 0      RIO DE JANEIRO            RJ                 ****     2010-01-03
# 1               BELÉM            PA                 SBBE     2010-01-03
# 2      RIO DE JANEIRO            RJ                 SBRJ     2010-01-03
# 3  LUCAS DO RIO VERDE            MT                 ****     2010-01-04
# 4             PELOTAS            RS                 SBPK     2010-01-05
# 5            SALVADOR            BA                 ****     2010-01-06
# 6               COARI            AM                 SBUY     2010-01-07
# 7            CANUTAMA            AM                 ****     2010-01-09
# 8            CASCAVEL            PR                 SBCA     2010-01-10
# 9       PARÁ DE MINAS            MG                 ****     2010-01-10
#
#   ocorrencia_hora  total_recomendacoes
# 0        12:00:00                    0
# 1        11:05:00                    0
# 2        03:00:00                    0
# 3        17:30:00                    0
# 4        19:25:00                    0
# 5        17:53:00                    0
# 6        18:40:00                    0
# 7        12:30:00                    3
# 8        23:15:00                    2
# 9        20:00:00                    0

# %% [markdown]
# Validation

# %%
schema = pa.DataFrameSchema(
    columns = {
        "codigo": pa.Column(pa.Int, required=False),
        "codigo_ocorrencia": pa.Column(pa.Int),
        "codigo_ocorrencia2": pa.Column(pa.Int),
        "ocorrencia_classificacao": pa.Column(pa.String),
        "ocorrencia_cidade": pa.Column(pa.String),
        "ocorrencia_uf": pa.Column(pa.String, pa.Check.str_length(2,2)),
        "ocorrencia_aerodromo": pa.Column(pa.String),
        "ocorrencia_dia": pa.Column(pa.DateTime),
        "ocorrencia_hora": pa.Column(pa.String,
                                     pa.Check.str_matches(r'^([0-1]?[0-9]|[2][0-3]):([0-5][0-9])(:[0-5][0-9])?$'),
                                     nullable = True),
        "total_recomendacoes": pa.Column(pa.Int)
    }
)

# %%
schema.validate(df)
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 0                 40211               40211                INCIDENTE
# 1                 40349               40349                INCIDENTE
# 2                 40351               40351                INCIDENTE
# 3                 39527               39527                 ACIDENTE
# 4                 40324               40324                INCIDENTE
# ...                 ...                 ...                      ...
# 5747              79804               79804                INCIDENTE
# 5748              79757               79757          INCIDENTE GRAVE
# 5749              79802               79802                INCIDENTE
# 5750              79756               79756          INCIDENTE GRAVE
# 5751              79844               79844                INCIDENTE
#
#        ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 0         RIO DE JANEIRO            RJ                 ****     2010-01-03
# 1                  BELÉM            PA                 SBBE     2010-01-03
# 2         RIO DE JANEIRO            RJ                 SBRJ     2010-01-03
# 3     LUCAS DO RIO VERDE            MT                 ****     2010-01-04
# 4                PELOTAS            RS                 SBPK     2010-01-05
# ...                  ...           ...                  ...            ...
# 5747            CAMPINAS            SP                 SBKP     2020-12-29
# 5748   LAGOA DA CONFUSÃO            TO                 ****     2020-12-30
# 5749      RIO DE JANEIRO            RJ                 SBGL     2020-12-30
# 5750           VICENTINA            MS                 ****     2020-12-31
# 5751      RIO DE JANEIRO            RJ                 SBJR     2020-12-31
#
#      ocorrencia_hora  total_recomendacoes
# 0           12:00:00                    0
# 1           11:05:00                    0
# 2           03:00:00                    0
# 3           17:30:00                    0
# 4           19:25:00                    0
# ...              ...                  ...
# 5747        19:00:00                    0
# 5748        18:30:00                    0
# 5749        00:54:00                    0
# 5750        09:00:00                    0
# 5751        13:24:00                    0
#
# [5752 rows x 9 columns]

# %% [raw]
# df.dtypes
# df.ocorrencia_dia.dt.month

# %%
df.loc[1, 'ocorrencia_cidade']
# Out:
# 'BELÉM'

# %%
df.loc[1:3]
# Out:
#    codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 1              40349               40349                INCIDENTE
# 2              40351               40351                INCIDENTE
# 3              39527               39527                 ACIDENTE
#
#     ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 1               BELÉM            PA                 SBBE     2010-01-03
# 2      RIO DE JANEIRO            RJ                 SBRJ     2010-01-03
# 3  LUCAS DO RIO VERDE            MT                 ****     2010-01-04
#
#   ocorrencia_hora  total_recomendacoes
# 1        11:05:00                    0
# 2        03:00:00                    0
# 3        17:30:00                    0

# %%
df.loc[[10,40]]
# Out:
#     codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 10              39789               39789                INCIDENTE
# 40              39158               39158                INCIDENTE
#
#    ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 10  SÃO PEDRO DO SUL            RS                 ****     2010-01-10
# 40             BELÉM            PA                 ****     2010-01-28
#
#    ocorrencia_hora  total_recomendacoes
# 10        21:30:00                    0
# 40        16:00:00                    0

# %% [markdown]
# # Data Cleaning

# %%
df.loc[:, 'ocorrencia_cidade']
# Out:
# 0           RIO DE JANEIRO
# 1                    BELÉM
# 2           RIO DE JANEIRO
# 3       LUCAS DO RIO VERDE
# 4                  PELOTAS
#                ...
# 5747              CAMPINAS
# 5748     LAGOA DA CONFUSÃO
# 5749        RIO DE JANEIRO
# 5750             VICENTINA
# 5751        RIO DE JANEIRO
# Name: ocorrencia_cidade, Length: 5752, dtype: object

# %%
df.codigo_ocorrencia.is_unique
# Out:
# True

# %%
df.set_index('codigo_ocorrencia', inplace=True)
df.head()
# Out:
#                    codigo_ocorrencia2 ocorrencia_classificacao  \
# codigo_ocorrencia
# 40211                           40211                INCIDENTE
# 40349                           40349                INCIDENTE
# 40351                           40351                INCIDENTE
# 39527                           39527                 ACIDENTE
# 40324                           40324                INCIDENTE
#
#                     ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo  \
# codigo_ocorrencia
# 40211                  RIO DE JANEIRO            RJ                 ****
# 40349                           BELÉM            PA                 SBBE
# 40351                  RIO DE JANEIRO            RJ                 SBRJ
# 39527              LUCAS DO RIO VERDE            MT                 ****
# 40324                         PELOTAS            RS                 SBPK
#
#                   ocorrencia_dia ocorrencia_hora  total_recomendacoes
# codigo_ocorrencia
# 40211                 2010-01-03        12:00:00                    0
# 40349                 2010-01-03        11:05:00                    0
# 40351                 2010-01-03        03:00:00                    0
# 39527                 2010-01-04        17:30:00                    0
# 40324                 2010-01-05        19:25:00                    0

# %%
df.loc[40324]
# Out:
# codigo_ocorrencia2                        40324
# ocorrencia_classificacao              INCIDENTE
# ocorrencia_cidade                       PELOTAS
# ocorrencia_uf                                RS
# ocorrencia_aerodromo                       SBPK
# ocorrencia_dia              2010-01-05 00:00:00
# ocorrencia_hora                        19:25:00
# total_recomendacoes                           0
# Name: 40324, dtype: object

# %%
df.reset_index(drop=True, inplace=True)

# %%
df.head()
# Out:
#    codigo_ocorrencia2 ocorrencia_classificacao   ocorrencia_cidade  \
# 0               40211                INCIDENTE      RIO DE JANEIRO
# 1               40349                INCIDENTE               BELÉM
# 2               40351                INCIDENTE      RIO DE JANEIRO
# 3               39527                 ACIDENTE  LUCAS DO RIO VERDE
# 4               40324                INCIDENTE             PELOTAS
#
#   ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia ocorrencia_hora  \
# 0            RJ                 ****     2010-01-03        12:00:00
# 1            PA                 SBBE     2010-01-03        11:05:00
# 2            RJ                 SBRJ     2010-01-03        03:00:00
# 3            MT                 ****     2010-01-04        17:30:00
# 4            RS                 SBPK     2010-01-05        19:25:00
#
#    total_recomendacoes
# 0                    0
# 1                    0
# 2                    0
# 3                    0
# 4                    0

# %%
df.loc[0,'ocorrencia_aerodromo'] = ''

# %%
df.head(1)
# Out:
#    codigo_ocorrencia2 ocorrencia_classificacao ocorrencia_cidade  \
# 0               40211                INCIDENTE    RIO DE JANEIRO
#
#   ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia ocorrencia_hora  \
# 0            RJ                          2010-01-03        12:00:00
#
#    total_recomendacoes
# 0                    0

# %%
df.head(1)
# Out:
#    codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 0              40211               40211                INCIDENTE
#
#   ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 0    RIO DE JANEIRO            RJ                 ****     2010-01-03
#
#   ocorrencia_hora  total_recomendacoes
# 0        12:00:00                    0

# %%
df.loc[1] = 20

# %%
df.head(2)
# Out:
#    codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 0              40211               40211                INCIDENTE
# 1                 20                  20                       20
#
#   ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo       ocorrencia_dia  \
# 0    RIO DE JANEIRO            RJ                 ****  2010-01-03 00:00:00
# 1                20            20                   20                   20
#
#   ocorrencia_hora  total_recomendacoes
# 0        12:00:00                    0
# 1              20                   20

# %%
df.loc[:, 'total_recomendacoes'] = 10
df
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 0                 40211               40211                INCIDENTE
# 1                    20                  20                       20
# 2                 40351               40351                INCIDENTE
# 3                 39527               39527                 ACIDENTE
# 4                 40324               40324                INCIDENTE
# ...                 ...                 ...                      ...
# 5747              79804               79804                INCIDENTE
# 5748              79757               79757          INCIDENTE GRAVE
# 5749              79802               79802                INCIDENTE
# 5750              79756               79756          INCIDENTE GRAVE
# 5751              79844               79844                INCIDENTE
#
#        ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo  \
# 0         RIO DE JANEIRO            RJ                 ****
# 1                     20            20                   20
# 2         RIO DE JANEIRO            RJ                 SBRJ
# 3     LUCAS DO RIO VERDE            MT                 ****
# 4                PELOTAS            RS                 SBPK
# ...                  ...           ...                  ...
# 5747            CAMPINAS            SP                 SBKP
# 5748   LAGOA DA CONFUSÃO            TO                 ****
# 5749      RIO DE JANEIRO            RJ                 SBGL
# 5750           VICENTINA            MS                 ****
# 5751      RIO DE JANEIRO            RJ                 SBJR
#
#            ocorrencia_dia ocorrencia_hora  total_recomendacoes
# 0     2010-01-03 00:00:00        12:00:00                   10
# 1                      20              20                   10
# 2     2010-01-03 00:00:00        03:00:00                   10
# 3     2010-01-04 00:00:00        17:30:00                   10
# 4     2010-01-05 00:00:00        19:25:00                   10
# ...                   ...             ...                  ...
# 5747  2020-12-29 00:00:00        19:00:00                   10
# 5748  2020-12-30 00:00:00        18:30:00                   10
# 5749  2020-12-30 00:00:00        00:54:00                   10
# 5750  2020-12-31 00:00:00        09:00:00                   10
# 5751  2020-12-31 00:00:00        13:24:00                   10
#
# [5752 rows x 9 columns]

# %%
df.loc[df.ocorrencia_uf == 'SP', ['ocorrencia_classificacao']] = 'GRAVE'
df
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 0                 40211               40211                INCIDENTE
# 1                    20                  20                       20
# 2                 40351               40351                INCIDENTE
# 3                 39527               39527                 ACIDENTE
# 4                 40324               40324                INCIDENTE
# ...                 ...                 ...                      ...
# 5747              79804               79804                    GRAVE
# 5748              79757               79757          INCIDENTE GRAVE
# 5749              79802               79802                INCIDENTE
# 5750              79756               79756          INCIDENTE GRAVE
# 5751              79844               79844                INCIDENTE
#
#        ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo  \
# 0         RIO DE JANEIRO            RJ                 ****
# 1                     20            20                   20
# 2         RIO DE JANEIRO            RJ                 SBRJ
# 3     LUCAS DO RIO VERDE            MT                 ****
# 4                PELOTAS            RS                 SBPK
# ...                  ...           ...                  ...
# 5747            CAMPINAS            SP                 SBKP
# 5748   LAGOA DA CONFUSÃO            TO                 ****
# 5749      RIO DE JANEIRO            RJ                 SBGL
# 5750           VICENTINA            MS                 ****
# 5751      RIO DE JANEIRO            RJ                 SBJR
#
#            ocorrencia_dia ocorrencia_hora  total_recomendacoes
# 0     2010-01-03 00:00:00        12:00:00                   10
# 1                      20              20                   10
# 2     2010-01-03 00:00:00        03:00:00                   10
# 3     2010-01-04 00:00:00        17:30:00                   10
# 4     2010-01-05 00:00:00        19:25:00                   10
# ...                   ...             ...                  ...
# 5747  2020-12-29 00:00:00        19:00:00                   10
# 5748  2020-12-30 00:00:00        18:30:00                   10
# 5749  2020-12-30 00:00:00        00:54:00                   10
# 5750  2020-12-31 00:00:00        09:00:00                   10
# 5751  2020-12-31 00:00:00        13:24:00                   10
#
# [5752 rows x 9 columns]

# %%
df.loc[df.ocorrencia_uf == 'SP']
df
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 0                 40211               40211                INCIDENTE
# 1                    20                  20                       20
# 2                 40351               40351                INCIDENTE
# 3                 39527               39527                 ACIDENTE
# 4                 40324               40324                INCIDENTE
# ...                 ...                 ...                      ...
# 5747              79804               79804                    GRAVE
# 5748              79757               79757          INCIDENTE GRAVE
# 5749              79802               79802                INCIDENTE
# 5750              79756               79756          INCIDENTE GRAVE
# 5751              79844               79844                INCIDENTE
#
#        ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo  \
# 0         RIO DE JANEIRO            RJ                 ****
# 1                     20            20                   20
# 2         RIO DE JANEIRO            RJ                 SBRJ
# 3     LUCAS DO RIO VERDE            MT                 ****
# 4                PELOTAS            RS                 SBPK
# ...                  ...           ...                  ...
# 5747            CAMPINAS            SP                 SBKP
# 5748   LAGOA DA CONFUSÃO            TO                 ****
# 5749      RIO DE JANEIRO            RJ                 SBGL
# 5750           VICENTINA            MS                 ****
# 5751      RIO DE JANEIRO            RJ                 SBJR
#
#            ocorrencia_dia ocorrencia_hora  total_recomendacoes
# 0     2010-01-03 00:00:00        12:00:00                   10
# 1                      20              20                   10
# 2     2010-01-03 00:00:00        03:00:00                   10
# 3     2010-01-04 00:00:00        17:30:00                   10
# 4     2010-01-05 00:00:00        19:25:00                   10
# ...                   ...             ...                  ...
# 5747  2020-12-29 00:00:00        19:00:00                   10
# 5748  2020-12-30 00:00:00        18:30:00                   10
# 5749  2020-12-30 00:00:00        00:54:00                   10
# 5750  2020-12-31 00:00:00        09:00:00                   10
# 5751  2020-12-31 00:00:00        13:24:00                   10
#
# [5752 rows x 9 columns]

# %%
df.loc[df.ocorrencia_aerodromo == '****', ['ocorrencia_aerodromo']] = pd.NA

# %%
df.head()
# Out:
#    codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 0              40211               40211                INCIDENTE
# 1                 20                  20                       20
# 2              40351               40351                INCIDENTE
# 3              39527               39527                 ACIDENTE
# 4              40324               40324                INCIDENTE
#
#     ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo       ocorrencia_dia  \
# 0      RIO DE JANEIRO            RJ                 <NA>  2010-01-03 00:00:00
# 1                  20            20                   20                   20
# 2      RIO DE JANEIRO            RJ                 SBRJ  2010-01-03 00:00:00
# 3  LUCAS DO RIO VERDE            MT                 <NA>  2010-01-04 00:00:00
# 4             PELOTAS            RS                 SBPK  2010-01-05 00:00:00
#
#   ocorrencia_hora  total_recomendacoes
# 0        12:00:00                   10
# 1              20                   10
# 2        03:00:00                   10
# 3        17:30:00                   10
# 4        19:25:00                   10

# %% [raw]
# ocorrencia_uf
# **
# ocorrencia_aerodromo
# ###!
# ####
# ****
# *****
# ocorrencia_hora
# NULL

# %%
df.replace(['**','###!','####', '*****','NULL'], pd.NA, inplace=True)

# %%
df
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 0                 40211               40211                INCIDENTE
# 1                    20                  20                       20
# 2                 40351               40351                INCIDENTE
# 3                 39527               39527                 ACIDENTE
# 4                 40324               40324                INCIDENTE
# ...                 ...                 ...                      ...
# 5747              79804               79804                    GRAVE
# 5748              79757               79757          INCIDENTE GRAVE
# 5749              79802               79802                INCIDENTE
# 5750              79756               79756          INCIDENTE GRAVE
# 5751              79844               79844                INCIDENTE
#
#        ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo  \
# 0         RIO DE JANEIRO            RJ                 <NA>
# 1                     20            20                   20
# 2         RIO DE JANEIRO            RJ                 SBRJ
# 3     LUCAS DO RIO VERDE            MT                 <NA>
# 4                PELOTAS            RS                 SBPK
# ...                  ...           ...                  ...
# 5747            CAMPINAS            SP                 SBKP
# 5748   LAGOA DA CONFUSÃO            TO                 <NA>
# 5749      RIO DE JANEIRO            RJ                 SBGL
# 5750           VICENTINA            MS                 <NA>
# 5751      RIO DE JANEIRO            RJ                 SBJR
#
#            ocorrencia_dia ocorrencia_hora  total_recomendacoes
# 0     2010-01-03 00:00:00        12:00:00                   10
# 1                      20              20                   10
# 2     2010-01-03 00:00:00        03:00:00                   10
# 3     2010-01-04 00:00:00        17:30:00                   10
# 4     2010-01-05 00:00:00        19:25:00                   10
# ...                   ...             ...                  ...
# 5747  2020-12-29 00:00:00        19:00:00                   10
# 5748  2020-12-30 00:00:00        18:30:00                   10
# 5749  2020-12-30 00:00:00        00:54:00                   10
# 5750  2020-12-31 00:00:00        09:00:00                   10
# 5751  2020-12-31 00:00:00        13:24:00                   10
#
# [5752 rows x 9 columns]

# %%
df.isna().sum()
# Out:
# codigo_ocorrencia              0
# codigo_ocorrencia2             0
# ocorrencia_classificacao       0
# ocorrencia_cidade              0
# ocorrencia_uf                  0
# ocorrencia_aerodromo        2181
# ocorrencia_dia                 0
# ocorrencia_hora                1
# total_recomendacoes            0
# dtype: int64

# %%
df.isnull().sum()
# Out:
# codigo_ocorrencia              0
# codigo_ocorrencia2             0
# ocorrencia_classificacao       0
# ocorrencia_cidade              0
# ocorrencia_uf                  0
# ocorrencia_aerodromo        2181
# ocorrencia_dia                 0
# ocorrencia_hora                1
# total_recomendacoes            0
# dtype: int64

# %%
df.fillna(10, inplace=True)
df.isnull().sum()
# Out:
# codigo_ocorrencia           0
# codigo_ocorrencia2          0
# ocorrencia_classificacao    0
# ocorrencia_cidade           0
# ocorrencia_uf               0
# ocorrencia_aerodromo        0
# ocorrencia_dia              0
# ocorrencia_hora             0
# total_recomendacoes         0
# dtype: int64

# %%
df.replace([10], pd.NA, inplace=True)

# %%
df.isnull().sum()
# Out:
# codigo_ocorrencia           0
# codigo_ocorrencia2          0
# ocorrencia_classificacao    0
# ocorrencia_cidade           0
# ocorrencia_uf               0
# ocorrencia_aerodromo        0
# ocorrencia_dia              0
# ocorrencia_hora             0
# total_recomendacoes         0
# dtype: int64

# %%
df.head()
# Out:
#    codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 0              40211               40211                INCIDENTE
# 1                 20                  20                       20
# 2              40351               40351                INCIDENTE
# 3              39527               39527                 ACIDENTE
# 4              40324               40324                INCIDENTE
#
#     ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo       ocorrencia_dia  \
# 0      RIO DE JANEIRO            RJ                   10  2010-01-03 00:00:00
# 1                  20            20                   20                   20
# 2      RIO DE JANEIRO            RJ                 SBRJ  2010-01-03 00:00:00
# 3  LUCAS DO RIO VERDE            MT                   10  2010-01-04 00:00:00
# 4             PELOTAS            RS                 SBPK  2010-01-05 00:00:00
#
#   ocorrencia_hora  total_recomendacoes
# 0        12:00:00                   10
# 1              20                   10
# 2        03:00:00                   10
# 3        17:30:00                   10
# 4        19:25:00                   10

# %%
df.replace([10], pd.NA, inplace=True)
df.isnull().sum()
# Out:
# codigo_ocorrencia              0
# codigo_ocorrencia2             0
# ocorrencia_classificacao       0
# ocorrencia_cidade              0
# ocorrencia_uf                  0
# ocorrencia_aerodromo        2181
# ocorrencia_dia                 0
# ocorrencia_hora                1
# total_recomendacoes         5752
# dtype: int64

# %%
df.fillna(value={'total_recomendacoes':10}, inplace=True)
df.isnull().sum()
# Out:
# codigo_ocorrencia              0
# codigo_ocorrencia2             0
# ocorrencia_classificacao       0
# ocorrencia_cidade              0
# ocorrencia_uf                  0
# ocorrencia_aerodromo        2181
# ocorrencia_dia                 0
# ocorrencia_hora                1
# total_recomendacoes            0
# dtype: int64

# %%
df['total_recomendacoes_bkp'] = df.total_recomendacoes
df.head()
# Out:
#    codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 0              40211               40211                INCIDENTE
# 1                 20                  20                       20
# 2              40351               40351                INCIDENTE
# 3              39527               39527                 ACIDENTE
# 4              40324               40324                INCIDENTE
#
#     ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo       ocorrencia_dia  \
# 0      RIO DE JANEIRO            RJ                 <NA>  2010-01-03 00:00:00
# 1                  20            20                   20                   20
# 2      RIO DE JANEIRO            RJ                 SBRJ  2010-01-03 00:00:00
# 3  LUCAS DO RIO VERDE            MT                 <NA>  2010-01-04 00:00:00
# 4             PELOTAS            RS                 SBPK  2010-01-05 00:00:00
#
#   ocorrencia_hora  total_recomendacoes  total_recomendacoes_bkp
# 0        12:00:00                 10.0                     10.0
# 1              20                 10.0                     10.0
# 2        03:00:00                 10.0                     10.0
# 3        17:30:00                 10.0                     10.0
# 4        19:25:00                 10.0                     10.0

# %%
df.drop(['total_recomendacoes_bkp'], axis=1, inplace=True)

# %%
df.head()
# Out:
#    codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 0              40211               40211                INCIDENTE
# 1                 20                  20                       20
# 2              40351               40351                INCIDENTE
# 3              39527               39527                 ACIDENTE
# 4              40324               40324                INCIDENTE
#
#     ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo       ocorrencia_dia  \
# 0      RIO DE JANEIRO            RJ                 <NA>  2010-01-03 00:00:00
# 1                  20            20                   20                   20
# 2      RIO DE JANEIRO            RJ                 SBRJ  2010-01-03 00:00:00
# 3  LUCAS DO RIO VERDE            MT                 <NA>  2010-01-04 00:00:00
# 4             PELOTAS            RS                 SBPK  2010-01-05 00:00:00
#
#   ocorrencia_hora  total_recomendacoes
# 0        12:00:00                 10.0
# 1              20                 10.0
# 2        03:00:00                 10.0
# 3        17:30:00                 10.0
# 4        19:25:00                 10.0

# %%
df.dropna()
df
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 0                 40211               40211                INCIDENTE
# 1                    20                  20                       20
# 2                 40351               40351                INCIDENTE
# 3                 39527               39527                 ACIDENTE
# 4                 40324               40324                INCIDENTE
# ...                 ...                 ...                      ...
# 5747              79804               79804                    GRAVE
# 5748              79757               79757          INCIDENTE GRAVE
# 5749              79802               79802                INCIDENTE
# 5750              79756               79756          INCIDENTE GRAVE
# 5751              79844               79844                INCIDENTE
#
#        ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo  \
# 0         RIO DE JANEIRO            RJ                 <NA>
# 1                     20            20                   20
# 2         RIO DE JANEIRO            RJ                 SBRJ
# 3     LUCAS DO RIO VERDE            MT                 <NA>
# 4                PELOTAS            RS                 SBPK
# ...                  ...           ...                  ...
# 5747            CAMPINAS            SP                 SBKP
# 5748   LAGOA DA CONFUSÃO            TO                 <NA>
# 5749      RIO DE JANEIRO            RJ                 SBGL
# 5750           VICENTINA            MS                 <NA>
# 5751      RIO DE JANEIRO            RJ                 SBJR
#
#            ocorrencia_dia ocorrencia_hora  total_recomendacoes
# 0     2010-01-03 00:00:00        12:00:00                 10.0
# 1                      20              20                 10.0
# 2     2010-01-03 00:00:00        03:00:00                 10.0
# 3     2010-01-04 00:00:00        17:30:00                 10.0
# 4     2010-01-05 00:00:00        19:25:00                 10.0
# ...                   ...             ...                  ...
# 5747  2020-12-29 00:00:00        19:00:00                 10.0
# 5748  2020-12-30 00:00:00        18:30:00                 10.0
# 5749  2020-12-30 00:00:00        00:54:00                 10.0
# 5750  2020-12-31 00:00:00        09:00:00                 10.0
# 5751  2020-12-31 00:00:00        13:24:00                 10.0
#
# [5752 rows x 9 columns]

# %%
df.dropna(subset=['ocorrencia_uf'])
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 0                 40211               40211                INCIDENTE
# 1                    20                  20                       20
# 2                 40351               40351                INCIDENTE
# 3                 39527               39527                 ACIDENTE
# 4                 40324               40324                INCIDENTE
# ...                 ...                 ...                      ...
# 5747              79804               79804                    GRAVE
# 5748              79757               79757          INCIDENTE GRAVE
# 5749              79802               79802                INCIDENTE
# 5750              79756               79756          INCIDENTE GRAVE
# 5751              79844               79844                INCIDENTE
#
#        ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo  \
# 0         RIO DE JANEIRO            RJ                 <NA>
# 1                     20            20                   20
# 2         RIO DE JANEIRO            RJ                 SBRJ
# 3     LUCAS DO RIO VERDE            MT                 <NA>
# 4                PELOTAS            RS                 SBPK
# ...                  ...           ...                  ...
# 5747            CAMPINAS            SP                 SBKP
# 5748   LAGOA DA CONFUSÃO            TO                 <NA>
# 5749      RIO DE JANEIRO            RJ                 SBGL
# 5750           VICENTINA            MS                 <NA>
# 5751      RIO DE JANEIRO            RJ                 SBJR
#
#            ocorrencia_dia ocorrencia_hora  total_recomendacoes
# 0     2010-01-03 00:00:00        12:00:00                 10.0
# 1                      20              20                 10.0
# 2     2010-01-03 00:00:00        03:00:00                 10.0
# 3     2010-01-04 00:00:00        17:30:00                 10.0
# 4     2010-01-05 00:00:00        19:25:00                 10.0
# ...                   ...             ...                  ...
# 5747  2020-12-29 00:00:00        19:00:00                 10.0
# 5748  2020-12-30 00:00:00        18:30:00                 10.0
# 5749  2020-12-30 00:00:00        00:54:00                 10.0
# 5750  2020-12-31 00:00:00        09:00:00                 10.0
# 5751  2020-12-31 00:00:00        13:24:00                 10.0
#
# [5752 rows x 9 columns]

# %%
df
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 0                 40211               40211                INCIDENTE
# 1                    20                  20                       20
# 2                 40351               40351                INCIDENTE
# 3                 39527               39527                 ACIDENTE
# 4                 40324               40324                INCIDENTE
# ...                 ...                 ...                      ...
# 5747              79804               79804                    GRAVE
# 5748              79757               79757          INCIDENTE GRAVE
# 5749              79802               79802                INCIDENTE
# 5750              79756               79756          INCIDENTE GRAVE
# 5751              79844               79844                INCIDENTE
#
#        ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo  \
# 0         RIO DE JANEIRO            RJ                 <NA>
# 1                     20            20                   20
# 2         RIO DE JANEIRO            RJ                 SBRJ
# 3     LUCAS DO RIO VERDE            MT                 <NA>
# 4                PELOTAS            RS                 SBPK
# ...                  ...           ...                  ...
# 5747            CAMPINAS            SP                 SBKP
# 5748   LAGOA DA CONFUSÃO            TO                 <NA>
# 5749      RIO DE JANEIRO            RJ                 SBGL
# 5750           VICENTINA            MS                 <NA>
# 5751      RIO DE JANEIRO            RJ                 SBJR
#
#            ocorrencia_dia ocorrencia_hora  total_recomendacoes
# 0     2010-01-03 00:00:00        12:00:00                 10.0
# 1                      20              20                 10.0
# 2     2010-01-03 00:00:00        03:00:00                 10.0
# 3     2010-01-04 00:00:00        17:30:00                 10.0
# 4     2010-01-05 00:00:00        19:25:00                 10.0
# ...                   ...             ...                  ...
# 5747  2020-12-29 00:00:00        19:00:00                 10.0
# 5748  2020-12-30 00:00:00        18:30:00                 10.0
# 5749  2020-12-30 00:00:00        00:54:00                 10.0
# 5750  2020-12-31 00:00:00        09:00:00                 10.0
# 5751  2020-12-31 00:00:00        13:24:00                 10.0
#
# [5752 rows x 9 columns]

# %%
df.drop_duplicates(inplace=True)

# %%
df
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 0                 40211               40211                INCIDENTE
# 1                    20                  20                       20
# 2                 40351               40351                INCIDENTE
# 3                 39527               39527                 ACIDENTE
# 4                 40324               40324                INCIDENTE
# ...                 ...                 ...                      ...
# 5747              79804               79804                    GRAVE
# 5748              79757               79757          INCIDENTE GRAVE
# 5749              79802               79802                INCIDENTE
# 5750              79756               79756          INCIDENTE GRAVE
# 5751              79844               79844                INCIDENTE
#
#        ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo  \
# 0         RIO DE JANEIRO            RJ                 <NA>
# 1                     20            20                   20
# 2         RIO DE JANEIRO            RJ                 SBRJ
# 3     LUCAS DO RIO VERDE            MT                 <NA>
# 4                PELOTAS            RS                 SBPK
# ...                  ...           ...                  ...
# 5747            CAMPINAS            SP                 SBKP
# 5748   LAGOA DA CONFUSÃO            TO                 <NA>
# 5749      RIO DE JANEIRO            RJ                 SBGL
# 5750           VICENTINA            MS                 <NA>
# 5751      RIO DE JANEIRO            RJ                 SBJR
#
#            ocorrencia_dia ocorrencia_hora  total_recomendacoes
# 0     2010-01-03 00:00:00        12:00:00                 10.0
# 1                      20              20                 10.0
# 2     2010-01-03 00:00:00        03:00:00                 10.0
# 3     2010-01-04 00:00:00        17:30:00                 10.0
# 4     2010-01-05 00:00:00        19:25:00                 10.0
# ...                   ...             ...                  ...
# 5747  2020-12-29 00:00:00        19:00:00                 10.0
# 5748  2020-12-30 00:00:00        18:30:00                 10.0
# 5749  2020-12-30 00:00:00        00:54:00                 10.0
# 5750  2020-12-31 00:00:00        09:00:00                 10.0
# 5751  2020-12-31 00:00:00        13:24:00                 10.0
#
# [5752 rows x 9 columns]
